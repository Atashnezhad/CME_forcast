# %% [markdown]
# # P03_02_Univar_LSTM

# %%
section_fig_main_title = 'P03_02_Univar_LSTM_'

# %%
import os, sys
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup as bs
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
from pandas.plotting import lag_plot

# %%
from sklearn.metrics import r2_score
from math import sqrt

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
# from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD

import math
from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %%
# !/Users/amin/anaconda3/bin/python -m pip install pmdarima
# !/Users/amin/anaconda3/bin/python -m pip install statsmodels

# %%
from pandas.plotting import autocorrelation_plot
import gif
import json

# %%
# !pip install statsmodels --upgrade
# !/Users/amin/anaconda3/bin/python -m pip install statsmodels --upgrade

# %%
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error

# %%
import tensorflow as tf
tf.__version__

import tensorflow as tf
from tensorflow import keras

import gif
from tqdm import tqdm

# %%
from sklearn import metrics
import statsmodels.api as sm

# %% [markdown]
# ## Read Data
#
# Using the univariate evenly spaced time series data from P03_01.

# %%
csv_path = "../Data/Data_ICME_speed_transformed_18D_P03_01"
df = pd.read_pickle(csv_path)

# %%
df.head()
# Out:
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-06-14    370.0
# 1996-07-02    360.0
# 1996-07-20    360.0
# 1996-08-07    360.0
# 1996-08-25    350.0
# Freq: 18D, Name: V_ICME (km/s) (i), dtype: float64

# %%
df.plot(figsize=(20,6))

# %% [markdown]
# ## Set data parameters

# %%
len(df)
# Out:
# 506

# %%
len(df)*.69
# Out:
# 349.14

# %%
# use first 347 timestamps for training 
size_of_training = 347

# %%
df[0:1].index[0]
# Out:
# Timestamp('1996-06-14 00:00:00', freq='18D')

# %%
# set the start of training row date
train_start = df[0:1].index[0]
train_start = str(train_start)
train_start
# Out:
# '1996-06-14 00:00:00'

# %%
a = df[0:1].index[0]
str(a)
# Out:
# '1996-06-14 00:00:00'

# %%
# set the end of training row date
train_end = df[(size_of_training-1):size_of_training].index[0]
train_end = str(train_end)
train_end
# Out:
# '2013-07-03 00:00:00'

# %%
# use last 60 time stamps for prediction one timestamps ahead (18 days ahead)
lags = 60

# %% [markdown]
# I subtract the length of training from whole data to come up with test data set length.

# %%
len(df) - 347
# Out:
# 159

# %% [markdown]
# I use the next 156 timestamps in the dataset as test data set which should be used for model prediction performance.
#
# however, I need to include the number of lags necessary for the test set. keep that in mind I need to separate the data from the main data set from row 347 to the end and, I have to subtract the 347 from 60 (lag time stamps) which later I would need for predicting the first row of the data set (I need 60 lags reading to forecast the next ICME speed).
#
# Let's find the date of the first row of the test data set.

# %%
next_timestamps_test_num = 156 # number of timestamps available for prediction - test set

# %%
print(size_of_training-lags)
# Out:
# 287

# %% [markdown]
# So the test data set row begin from row number 287. let's check out the date asigned to row 287.

# %%
df[287:288].index[0]
# Out:
# Timestamp('2010-08-06 00:00:00', freq='18D')

# %%
test_start = df[(size_of_training-lags-1):(size_of_training-lags)].index[0]
test_start = str(test_start)
test_start
# Out:
# '2010-07-19 00:00:00'

# %% [markdown]
# test data set should come to end at 503 (the end of whole data set = len(df)). lets check out the date asigned to row 503.

# %%
df[502:503].index[0]
# Out:
# Timestamp('2021-03-11 00:00:00', freq='18D')

# %%
test_end = df[(size_of_training+next_timestamps_test_num-1):(size_of_training+next_timestamps_test_num)].index[0]
test_end = str(test_end)
test_end
# Out:
# '2021-03-11 00:00:00'

# %% [markdown]
# ### Train and Test df

# %%
training_set = df[train_start:train_end]
test_set = df[test_start:test_end]

# %%
# We have chosen 'High' attribute for prices. Let's see what it looks like
training_set.plot(figsize=(16,6),legend=True)
test_set.plot(figsize=(16,6),legend=True)
plt.legend(['Training set (first 347)','Test set (next 157 time stamps)'])
plt.title('ICME km/s')
plt.show()

# %% [markdown]
# ## Preparing train data set

# %%
# training_set.values
training_set_np = np.array(training_set)
# training_set_np
training_set_np = training_set_np.reshape(-1,1)
# training_set_np

# %%
# Scaling the training set
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set_np)

# %%
training_set_scaled.size
# Out:
# 347

# %% [markdown]
# Using 60 timestamps for pridction next timestamp.

# %%
X_train = []
y_train = []

num_use_past_data = lags # 60
size_of_training = training_set_scaled.size 



for i in range(num_use_past_data, size_of_training):
    X_train.append(training_set_scaled[i-num_use_past_data:i, 0])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train.shape
# Out:
# (287, 60)

# %%
y_train.shape
# Out:
# (287,)

# %%
# Reshaping X_train for efficient modelling
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

# %% [markdown]
# ## LSTM_1

# %%
# lstm source https://www.kaggle.com/thebrownviking20/intro-to-recurrent-neural-networks-lstm-gru
# The LSTM architecture
regressor = Sequential()
# First LSTM layer with Dropout regularisation
regressor.add(LSTM(units=4, return_sequences=True, 
                   input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.2))


# # Second LSTM layer
# regressor.add(LSTM(units=50, return_sequences=True))
# regressor.add(Dropout(0.2))


# # Third LSTM layer
# regressor.add(LSTM(units=50, return_sequences=True))
# regressor.add(Dropout(0.2))


# Fourth LSTM layer
regressor.add(LSTM(units=4))
regressor.add(Dropout(0.2))



# The output layer
regressor.add(Dense(units=1))


# Compiling the RNN
regressor.compile(optimizer='rmsprop', 
                  loss='mean_squared_error')

# %%
regressor.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 60, 4)             96
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 60, 4)             0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 4)                 144
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 4)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 245
# Trainable params: 245
# Non-trainable params: 0
# _________________________________________________________________

# %%
path_checkpoint = "../Models/P03_02_LSTM_1_univariate.h5"
# es_callback = keras.callbacks.EarlyStopping(monitor="loss", 
#                                             min_delta=0, 
#                                             patience=5)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
                                                    monitor="loss",
                                                    filepath=path_checkpoint,
                                                    verbose=0,
                                                    #save_weights_only=True,
                                                    #save_best_only=True,
                                                    )


# Fitting to the training set


history = regressor.fit(X_train, y_train,
                    epochs=100,
                    validation_split=0.2,
                    callbacks=[modelckpt_callback], #es_callback, 
                )
# Out:
# Train on 229 samples, validate on 58 samples
# Epoch 1/100
# 229/229 [==============================] - 3s 14ms/sample - loss: 0.0294 - val_loss: 0.0244
# Epoch 2/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0273 - val_loss: 0.0225
# Epoch 3/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0270 - val_loss: 0.0225
# Epoch 4/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0265 - val_loss: 0.0220
# Epoch 5/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0269 - val_loss: 0.0218
# Epoch 6/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0263 - val_loss: 0.0221
# Epoch 7/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0261 - val_loss: 0.0222
# Epoch 8/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0258 - val_loss: 0.0215
# Epoch 9/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0259 - val_loss: 0.0215
# Epoch 10/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0259 - val_loss: 0.0216
# Epoch 11/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0260 - val_loss: 0.0211
# Epoch 12/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0256 - val_loss: 0.0226
# Epoch 13/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0257 - val_loss: 0.0212
# Epoch 14/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0252 - val_loss: 0.0209
# Epoch 15/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0251 - val_loss: 0.0210
# Epoch 16/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0249 - val_loss: 0.0205
# Epoch 17/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0250 - val_loss: 0.0204
# Epoch 18/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0249 - val_loss: 0.0204
# Epoch 19/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0249 - val_loss: 0.0214
# Epoch 20/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0255 - val_loss: 0.0204
# Epoch 21/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0246 - val_loss: 0.0200
# Epoch 22/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0247 - val_loss: 0.0199
# Epoch 23/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0243 - val_loss: 0.0198
# Epoch 24/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0243 - val_loss: 0.0197
# Epoch 25/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0247 - val_loss: 0.0197
# Epoch 26/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0245 - val_loss: 0.0202
# Epoch 27/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0243 - val_loss: 0.0197
# Epoch 28/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0241 - val_loss: 0.0194
# Epoch 29/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0239 - val_loss: 0.0195
# Epoch 30/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0238 - val_loss: 0.0197
# Epoch 31/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0238 - val_loss: 0.0191
# Epoch 32/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0238 - val_loss: 0.0192
# Epoch 33/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0236 - val_loss: 0.0191
# Epoch 34/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0236 - val_loss: 0.0191
# Epoch 35/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0236 - val_loss: 0.0194
# Epoch 36/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0238 - val_loss: 0.0192
# Epoch 37/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0235 - val_loss: 0.0193
# Epoch 38/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0234 - val_loss: 0.0191
# Epoch 39/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0233 - val_loss: 0.0193
# Epoch 40/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0234 - val_loss: 0.0194
# Epoch 41/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0233 - val_loss: 0.0190
# Epoch 42/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0238 - val_loss: 0.0190
# Epoch 43/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0237 - val_loss: 0.0199
# Epoch 44/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0234 - val_loss: 0.0189
# Epoch 45/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0235 - val_loss: 0.0189
# Epoch 46/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0234 - val_loss: 0.0190
# Epoch 47/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0235 - val_loss: 0.0191
# Epoch 48/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0231 - val_loss: 0.0198
# Epoch 49/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0236 - val_loss: 0.0193
# Epoch 50/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0232 - val_loss: 0.0191
# Epoch 51/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0232 - val_loss: 0.0194
# Epoch 52/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0232 - val_loss: 0.0191
# Epoch 53/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0240 - val_loss: 0.0191
# Epoch 54/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0233 - val_loss: 0.0192
# Epoch 55/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0232 - val_loss: 0.0193
# Epoch 56/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0232 - val_loss: 0.0192
# Epoch 57/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0230 - val_loss: 0.0194
# Epoch 58/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0236 - val_loss: 0.0191
# Epoch 59/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0231 - val_loss: 0.0192
# Epoch 60/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0239 - val_loss: 0.0190
# Epoch 61/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0230 - val_loss: 0.0197
# Epoch 62/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0238 - val_loss: 0.0199
# Epoch 63/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0232 - val_loss: 0.0191
# Epoch 64/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0234 - val_loss: 0.0192
# Epoch 65/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0230 - val_loss: 0.0192
# Epoch 66/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0230 - val_loss: 0.0194
# Epoch 67/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0232 - val_loss: 0.0193
# Epoch 68/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0230 - val_loss: 0.0192
# Epoch 69/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0233 - val_loss: 0.0191
# Epoch 70/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0233 - val_loss: 0.0193
# Epoch 71/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0230 - val_loss: 0.0191
# Epoch 72/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0233 - val_loss: 0.0192
# Epoch 73/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0232 - val_loss: 0.0193
# Epoch 74/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0233 - val_loss: 0.0195
# Epoch 75/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0230 - val_loss: 0.0192
# Epoch 76/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0231 - val_loss: 0.0193
# Epoch 77/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0231 - val_loss: 0.0191
# Epoch 78/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0230 - val_loss: 0.0193
# Epoch 79/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0232 - val_loss: 0.0191
# Epoch 80/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0231 - val_loss: 0.0192
# Epoch 81/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0238 - val_loss: 0.0198
# Epoch 82/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0242 - val_loss: 0.0190
# Epoch 83/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0229 - val_loss: 0.0193
# Epoch 84/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0230 - val_loss: 0.0194
# Epoch 85/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0231 - val_loss: 0.0194
# Epoch 86/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0231 - val_loss: 0.0192
# Epoch 87/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0229 - val_loss: 0.0192
# Epoch 88/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0229 - val_loss: 0.0192
# Epoch 89/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0229 - val_loss: 0.0192
# Epoch 90/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0230 - val_loss: 0.0196
# Epoch 91/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0230 - val_loss: 0.0194
# Epoch 92/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0229 - val_loss: 0.0194
# Epoch 93/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0228 - val_loss: 0.0194
# Epoch 94/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0230 - val_loss: 0.0196
# Epoch 95/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0230 - val_loss: 0.0195
# Epoch 96/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0230 - val_loss: 0.0194
# Epoch 97/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0228 - val_loss: 0.0196
# Epoch 98/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0228 - val_loss: 0.0197
# Epoch 99/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0229 - val_loss: 0.0196
# Epoch 100/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0227 - val_loss: 0.0194

# %%
def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.ylim(0,)
    plt.xlabel('Epoch')
    plt.ylabel('Error V_ICME (km/s) (i)')
    plt.legend()
    plt.grid(True)

# %%
plot_loss(history)

# %%
model_history_df = pd.DataFrame(history.history)
model_history_df.columns
# Out:
# Index(['loss', 'val_loss'], dtype='object')

# %% [markdown]
# ## LSTM_2

# %%
# shape=(inputs.shape[1], )
# shape

# %%
inputs = X_train


inputs = keras.layers.Input(shape=(inputs.shape[1], 
                                   inputs.shape[2]))

lstm_out = keras.layers.LSTM(4)(inputs)

outputs = keras.layers.Dense(1)(lstm_out)

# lstm_out = keras.layers.LSTM(32)(inputs)
# outputs2 = keras.layers.LSTM(32)(outputs)


model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(), 
              loss="mse")

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 60, 1)             0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 4)                 96
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
inputs.shape
# Out:
# TensorShape([Dimension(None), Dimension(60), Dimension(1)])

# %%
# outputs2.shape

# %%
path_checkpoint = "../Models/P03_02_LSTM_2_univariate.h5"
# es_callback = keras.callbacks.EarlyStopping(monitor="loss", 
#                                             min_delta=0, 
#                                             patience=5)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
                                                    monitor="loss",
                                                    filepath=path_checkpoint,
                                                    verbose=0,
                                                    #save_weights_only=True,
                                                    #save_best_only=True,
                                                    )

history = model.fit(X_train, y_train,
                    epochs=100,
                    validation_split=0.2,
                    callbacks=[modelckpt_callback], #es_callback, 
                )
# Out:
# Train on 229 samples, validate on 58 samples
# Epoch 1/100
# 229/229 [==============================] - 4s 20ms/sample - loss: 0.1801 - val_loss: 0.1156
# Epoch 2/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.1551 - val_loss: 0.0986
# Epoch 3/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.1356 - val_loss: 0.0851
# Epoch 4/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.1194 - val_loss: 0.0742
# Epoch 5/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.1064 - val_loss: 0.0652
# Epoch 6/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0952 - val_loss: 0.0576
# Epoch 7/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0854 - val_loss: 0.0509
# Epoch 8/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0770 - val_loss: 0.0450
# Epoch 9/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0692 - val_loss: 0.0400
# Epoch 10/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0625 - val_loss: 0.0356
# Epoch 11/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0563 - val_loss: 0.0318
# Epoch 12/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0508 - val_loss: 0.0287
# Epoch 13/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0458 - val_loss: 0.0264
# Epoch 14/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0421 - val_loss: 0.0246
# Epoch 15/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0387 - val_loss: 0.0236
# Epoch 16/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0362 - val_loss: 0.0231
# Epoch 17/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0343 - val_loss: 0.0231
# Epoch 18/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0330 - val_loss: 0.0234
# Epoch 19/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0323 - val_loss: 0.0239
# Epoch 20/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0318 - val_loss: 0.0245
# Epoch 21/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0316 - val_loss: 0.0251
# Epoch 22/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0314 - val_loss: 0.0253
# Epoch 23/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0314 - val_loss: 0.0255
# Epoch 24/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0313 - val_loss: 0.0255
# Epoch 25/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0312 - val_loss: 0.0253
# Epoch 26/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0311 - val_loss: 0.0249
# Epoch 27/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0311 - val_loss: 0.0245
# Epoch 28/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0311 - val_loss: 0.0243
# Epoch 29/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0310 - val_loss: 0.0244
# Epoch 30/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0309 - val_loss: 0.0246
# Epoch 31/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0308 - val_loss: 0.0247
# Epoch 32/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0307 - val_loss: 0.0245
# Epoch 33/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0307 - val_loss: 0.0246
# Epoch 34/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0306 - val_loss: 0.0244
# Epoch 35/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0305 - val_loss: 0.0245
# Epoch 36/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0304 - val_loss: 0.0247
# Epoch 37/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0304 - val_loss: 0.0249
# Epoch 38/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0303 - val_loss: 0.0246
# Epoch 39/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0302 - val_loss: 0.0247
# Epoch 40/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0302 - val_loss: 0.0245
# Epoch 41/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0301 - val_loss: 0.0246
# Epoch 42/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0300 - val_loss: 0.0248
# Epoch 43/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0300 - val_loss: 0.0249
# Epoch 44/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0299 - val_loss: 0.0247
# Epoch 45/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0298 - val_loss: 0.0245
# Epoch 46/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0298 - val_loss: 0.0242
# Epoch 47/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0298 - val_loss: 0.0243
# Epoch 48/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0297 - val_loss: 0.0242
# Epoch 49/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0296 - val_loss: 0.0240
# Epoch 50/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0296 - val_loss: 0.0240
# Epoch 51/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0295 - val_loss: 0.0240
# Epoch 52/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0295 - val_loss: 0.0241
# Epoch 53/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0294 - val_loss: 0.0242
# Epoch 54/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0294 - val_loss: 0.0243
# Epoch 55/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0293 - val_loss: 0.0242
# Epoch 56/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0293 - val_loss: 0.0245
# Epoch 57/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0293 - val_loss: 0.0246
# Epoch 58/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0292 - val_loss: 0.0242
# Epoch 59/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0291 - val_loss: 0.0240
# Epoch 60/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0290 - val_loss: 0.0240
# Epoch 61/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0290 - val_loss: 0.0239
# Epoch 62/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0289 - val_loss: 0.0239
# Epoch 63/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0289 - val_loss: 0.0235
# Epoch 64/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0289 - val_loss: 0.0234
# Epoch 65/100
# 229/229 [==============================] - 0s 1ms/sample - loss: 0.0288 - val_loss: 0.0236
# Epoch 66/100
# 229/229 [==============================] - 0s 1ms/sample - loss: 0.0287 - val_loss: 0.0237
# Epoch 67/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0287 - val_loss: 0.0237
# Epoch 68/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0286 - val_loss: 0.0235
# Epoch 69/100
# 229/229 [==============================] - 0s 1ms/sample - loss: 0.0286 - val_loss: 0.0232
# Epoch 70/100
# 229/229 [==============================] - 0s 1ms/sample - loss: 0.0286 - val_loss: 0.0230
# Epoch 71/100
# 229/229 [==============================] - 0s 1ms/sample - loss: 0.0285 - val_loss: 0.0229
# Epoch 72/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0285 - val_loss: 0.0230
# Epoch 73/100
# 229/229 [==============================] - 0s 1ms/sample - loss: 0.0284 - val_loss: 0.0233
# Epoch 74/100
# 229/229 [==============================] - 0s 1ms/sample - loss: 0.0283 - val_loss: 0.0232
# Epoch 75/100
# 229/229 [==============================] - 0s 1ms/sample - loss: 0.0283 - val_loss: 0.0231
# Epoch 76/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0283 - val_loss: 0.0232
# Epoch 77/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0282 - val_loss: 0.0231
# Epoch 78/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0282 - val_loss: 0.0232
# Epoch 79/100
# 229/229 [==============================] - 0s 1ms/sample - loss: 0.0281 - val_loss: 0.0232
# Epoch 80/100
# 229/229 [==============================] - 0s 1ms/sample - loss: 0.0281 - val_loss: 0.0230
# Epoch 81/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0280 - val_loss: 0.0230
# Epoch 82/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0280 - val_loss: 0.0230
# Epoch 83/100
# 229/229 [==============================] - 0s 1ms/sample - loss: 0.0280 - val_loss: 0.0230
# Epoch 84/100
# 229/229 [==============================] - 0s 1ms/sample - loss: 0.0279 - val_loss: 0.0230
# Epoch 85/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0279 - val_loss: 0.0229
# Epoch 86/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0279 - val_loss: 0.0229
# Epoch 87/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0278 - val_loss: 0.0227
# Epoch 88/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0279 - val_loss: 0.0227
# Epoch 89/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0277 - val_loss: 0.0232
# Epoch 90/100
# 229/229 [==============================] - 0s 1ms/sample - loss: 0.0277 - val_loss: 0.0234
# Epoch 91/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0277 - val_loss: 0.0234
# Epoch 92/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0278 - val_loss: 0.0236
# Epoch 93/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0276 - val_loss: 0.0231
# Epoch 94/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0275 - val_loss: 0.0228
# Epoch 95/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0276 - val_loss: 0.0231
# Epoch 96/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0274 - val_loss: 0.0229
# Epoch 97/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0275 - val_loss: 0.0226
# Epoch 98/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0274 - val_loss: 0.0228
# Epoch 99/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0273 - val_loss: 0.0228
# Epoch 100/100
# 229/229 [==============================] - 0s 2ms/sample - loss: 0.0273 - val_loss: 0.0228

# %%
plot_loss(history)

# %% [markdown]
# ## Preparing test data set

# %%
# test_set.values
test_set_np = np.array(test_set)
# test_set_np
test_set_np = test_set_np.reshape(-1,1)
# test_set_np

# %%
# Scaling the test set
inputs = sc.fit_transform(test_set_np)

# %% [markdown]
# ## Load the Model

# %%
# path = '../Models/LSTM_1_univariate.h5'
path = '../Models/LSTM_2_univariate.h5'
regressor = keras.models.load_model(path)

# %%
regressor.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 60, 1)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                4352
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Preparing X_test and prediction
X_test = []
for i in range(lags,(next_timestamps_test_num+lags)):
    X_test.append(inputs[i-lags:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_ICME = regressor.predict(X_test)
predicted_ICME = sc.inverse_transform(predicted_ICME)

# %% [markdown]
# seperate the correct test data set and cut off the first 60 lags.

# %%
test_set_edited = test_set[61:]
test_set_edited.size
# Out:
# 156

# %% [markdown]
# make sure that the data is in same format.

# %%
print(type(predicted_ICME))
print(type(np.array(test_set_edited)))
test_set_edited_np = np.array(test_set_edited)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
# predictions = pd.Series(predicted_ICME)
# predictions.index = test_set_edited_np.index

# %%
plt.plot(np.array(df[200:347]), 'k',label='history')

# %%
training_set.plot()

# %%
test_set
# Out:
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 2010-07-19    360.0
# 2010-08-06    530.0
# 2010-08-24    530.0
# 2010-09-11    530.0
# 2010-09-29    530.0
#               ...
# 2020-12-29    440.0
# 2021-01-16    440.0
# 2021-02-03    440.0
# 2021-02-21    440.0
# 2021-03-11    510.0
# Freq: 18D, Name: V_ICME (km/s) (i), Length: 217, dtype: float64

# %% [markdown]
# using test set series and replacing the values with a predicted values which I later use for plot purposes.

# %%
len(predicted_ICME)
# Out:
# 156

# %%
predicted_ICME.shape
# Out:
# (156, 1)

# %%
predicted_ICME_reshaped = predicted_ICME.reshape(-1,)
predicted_ICME_reshaped.shape
# Out:
# (156,)

# %%
predicted_ICME_timeseri = test_set[61:]
print('predicted_ICME_timeseri \n\n',predicted_ICME_timeseri.head())

print('\nshape \n\n', predicted_ICME_timeseri.shape)

type(predicted_ICME_timeseri)
type(predicted_ICME)

predicted_ICME_reshaped = predicted_ICME.reshape(-1, )
predicted_ICME_reshaped_ser = pd.Series(predicted_ICME_reshaped)


predicted_ICME_reshaped_ser.index = test_set[61:].index
predicted_ICME_reshaped_ser
# predicted_ICME_timeseri.values = predicted_ICME_reshaped
df[347:348][0]
# Out:
# predicted_ICME_timeseri
#
#  ICME Plasma/Field Start Y/M/D (UT) (b)
# 2013-07-21    430.0
# 2013-08-08    430.0
# 2013-08-26    400.0
# 2013-09-13    400.0
# 2013-10-01    400.0
# Freq: 18D, Name: V_ICME (km/s) (i), dtype: float64
#
# shape
#
#  (156,)
# 430.0

# %%
# test_set[61:]

# %%
# predicted_ICME_reshaped_ser

# %%
plt.scatter(predicted_ICME_reshaped_ser, test_set[61:])

# %%
real_values = test_set[61:]
predited_values = predicted_ICME_reshaped_ser



coefficient_of_dermination = r2_score(real_values, predited_values)
coefficient_of_dermination
# Out:
# 0.07968097813490616

# %%
# evaluate forecasts
rmse = sqrt(mean_squared_error(real_values, predited_values))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 66.324

# %%
# lstm1_P03_02_performance = {'R_sq': r2_score(real_values, predited_values),
#                                 'rmse': sqrt(mean_squared_error(real_values, predited_values))}

# # https://stackoverflow.com/questions/27745500/how-to-save-a-list-to-a-file-and-read-it-as-a-list-type
# with open("../Data/lstm1_P03_02_performance.json", 'w') as f:
#     # indent=2 is not needed but makes the file human-readable
#     json.dump(lstm1_P03_02_performance, f, indent=2)

# %%
lstm2_P03_02_performance = {'R_sq': r2_score(real_values, predited_values),
                                'rmse': sqrt(mean_squared_error(real_values, predited_values))}

# https://stackoverflow.com/questions/27745500/how-to-save-a-list-to-a-file-and-read-it-as-a-list-type
with open("../Data/lstm2_P03_02_performance.json", 'w') as f:
    # indent=2 is not needed but makes the file human-readable
    json.dump(lstm2_P03_02_performance, f, indent=2)

# %%
rs2 = round(coefficient_of_dermination,2)

# %%
plt.figure(figsize=(10,10))

real_values = test_set[61:]
predited_values = predicted_ICME_reshaped_ser

plt.scatter(real_values, predited_values, color='r', 
            alpha=0.4, label=f'Model vs Data | R2 = {rs2}',s=100)
plt.xlabel("ICME km/s data", fontsize=14)
plt.ylabel("ICME km/s predicted", fontsize=14)
plt.xticks(fontsize=12), plt.yticks(fontsize=12)
# plt.axline([0, 0], [1, 1], color ='k')
# plt.hlines(300, 300, 600, linestyles="--", color ='k')
# plt.vlines(300, 300, 600, linestyles="--", color ='k')

plt.xlim(300,650), plt.ylim(300,650)

plt.title("LSTM model ICME forcast results for 18 \
Days ahead\nData from 60 timestamps (60*18 Days) lags is used for prediction", fontsize=14)

plt.tight_layout()
plt.legend(fontsize=14)

plt.savefig("../Figures/" + section_fig_main_title + "LSTM_18days_Ahead.png")

# %%
# Some functions to help out with
# lstm source https://www.kaggle.com/thebrownviking20/intro-to-recurrent-neural-networks-lstm-gru
def plot_predictions(test, predicted, past, ahead):
    plt.figure(figsize=(16,8))
    
    plt.plot(df[(347-past):348], 'r',label='history')
    plt.vlines(df[347:348].index,0, 700, colors='k', linestyles='dashed')
    
    plt.plot(test[0:ahead], 'r^',label='Test')
    plt.plot(test[0:ahead], 'r')
#     test.plot(kind='scatter')
    
    plt.plot(predicted[0:ahead], color='blue',label='Predicted')
    plt.title('LSTM model', fontsize=10)
    plt.xlabel('Date', fontsize=10)
    plt.ylabel('ICME km/s', fontsize=10)
    
    
    
    
    plt.xticks(fontsize=10), plt.yticks(fontsize=10)
    plt.legend(fontsize=10)
    plt.ylim(200,)
    
#     plt.show()

# %%
# Visualizing the results for LSTM
plot_predictions(test_set[61:], predicted_ICME_reshaped_ser, past=100, ahead=100)

# %%
# return_rmse(test_set_edited_np,predicted_temp)

# %%
# predicted_temp_reshape = np.reshape(predicted_temp, (156,))

# %%
# test_set_edited_np.shape

# %% [markdown]
# both test and predicted values are in same format and same shape.

# %%
# test_part = test_set_edited_np[0:3]
# test_part

# %%
# predicted_temp_reshape_part = predicted_temp_reshape[0:3]
# predicted_temp_reshape_part

# %% [markdown]
# ## GIF visualization

# %%
plot_predictions(test_set[61:], predicted_ICME_reshaped_ser, past=100, ahead=100)

# %%
@gif.frame
def plott(i):
    plot_predictions(test_set[61:], predicted_ICME_reshaped_ser, past=100, ahead=i)
    
    
    
#     test_part = test_set_edited_np[0:i]
#     predicted_temp_reshape_part = predicted_temp_reshape[0:i]

#     plot_predictions(test_part, predicted_temp_reshape_part)

# %%
frames = []    
for i in tqdm(range(0,156)):

    
    frame =  plott(i)
    frames.append(frame)
# Out:
# 100%|██████████| 156/156 [00:20<00:00,  7.54it/s]

# %%
gif.save(frames, "../Figures/P03_02_LSTM_2_univar.gif", duration=2)
