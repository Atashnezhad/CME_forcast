# %% [markdown]
# # P03_05_Multivar_LSTM

# %%
section_fig_main_title = 'P03_05_Multivar_LSTM_'

# %%
import os, sys
import requests
from urllib.parse import urljoin, urlparse
# from bs4 import BeautifulSoup as bs
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
from pandas.plotting import lag_plot

from tensorflow import keras
# Out:
# /Users/amin/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/amin/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/amin/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/amin/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/amin/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/amin/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# !which python
# Out:
# /Users/amin/miniconda3/bin/python

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
# !/Users/amin/Desktop/proj/env/bin/python -m pip install xgboost

# %%
from sklearn.metrics import r2_score,mean_absolute_error
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/y0/960g9wv95_j3h357d8zwrxy00000gn/T/ipykernel_50280/2922162970.py in <module>
# ----> 1 from sklearn.metrics import r2_score,mean_absolute_error
#
# ~/Desktop/proj/env/lib/python3.7/site-packages/sklearn/__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# ~/Desktop/proj/env/lib/python3.7/site-packages/sklearn/base.py in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#
# ~/Desktop/proj/env/lib/python3.7/site-packages/sklearn/utils/__init__.py in <module>
#      26 from ..exceptions import DataConversionWarning
#      27 from .deprecation import deprecated
# ---> 28 from .fixes import np_version, parse_version
#      29 from ._estimator_html_repr import estimator_html_repr
#      30 from .validation import (
#
# ~/Desktop/proj/env/lib/python3.7/site-packages/sklearn/utils/fixes.py in <module>
#      17 import scipy.sparse as sp
#      18 import scipy
# ---> 19 import scipy.stats
#      20 from scipy.sparse.linalg import lsqr as sparse_lsqr  # noqa
#      21 from .._config import config_context, get_config
#
# ~/Desktop/proj/env/lib/python3.7/site-packages/scipy/stats/__init__.py in <module>
#     439 """
#     440
# --> 441 from .stats import *
#     442 from .distributions import *
#     443 from .morestats import *
#
# ~/Desktop/proj/env/lib/python3.7/site-packages/scipy/stats/stats.py in <module>
#      41 import scipy.special as special
#      42 from scipy import linalg
# ---> 43 from . import distributions
#      44 from . import mstats_basic
#      45 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#
# ~/Desktop/proj/env/lib/python3.7/site-packages/scipy/stats/distributions.py in <module>
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
# ----> 8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)
#       9
#      10 from . import _continuous_distns
#
# ~/Desktop/proj/env/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py in <module>
#      22 # for root finding for continuous distribution ppf, and max likelihood
#      23 # estimation
# ---> 24 from scipy import optimize
#      25
#      26 # for functions of continuous distributions (e.g. moments, entropy, cdf)
#
# ~/Desktop/proj/env/lib/python3.7/site-packages/scipy/optimize/__init__.py in <module>
#     411 from ._nnls import nnls
#     412 from ._basinhopping import basinhopping
# --> 413 from ._linprog import linprog, linprog_verbose_callback
#     414 from ._lsap import linear_sum_assignment
#     415 from ._differentialevolution import differential_evolution
#
# ~/Desktop/proj/env/lib/python3.7/site-packages/scipy/optimize/_linprog.py in <module>
#      20 from .optimize import OptimizeResult, OptimizeWarning
#      21 from warnings import warn
# ---> 22 from ._linprog_highs import _linprog_highs
#      23 from ._linprog_ip import _linprog_ip
#      24 from ._linprog_simplex import _linprog_simplex
#
# ~/Desktop/proj/env/lib/python3.7/site-packages/scipy/optimize/_linprog_highs.py in <module>
#      18 from .optimize import _check_unknown_options, OptimizeWarning, OptimizeResult
#      19 from warnings import warn
# ---> 20 from ._highs._highs_wrapper import _highs_wrapper
#      21 from ._highs._highs_constants import (
#      22     CONST_I_INF,
#
# ModuleNotFoundError: No module named 'scipy.optimize._highs._highs_wrapper'

# %%
# !/Users/amin/anaconda3/bin/python -m pip install --upgrade tensorflow 
# pip install --upgrade tensorflow

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
# from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD

import math
from sklearn.metrics import mean_squared_error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %%
from pandas.plotting import autocorrelation_plot
import gif

# %%
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.13.1'

# %%
import gif
from tqdm import tqdm

# %%
from sklearn import metrics
import statsmodels.api as sm

# %% [markdown]
# ## Read Data
#
# Using the univariate evenly spaced time series data from P03_01.

# %%
csv_path = "../Data/Data_ICME_Edited_Decoded_out_P02_03.csv"
df = pd.read_csv(csv_path)

# %%
df.index = df['ICME Plasma/Field Start Y/M/D (UT) (b)']

# %%
df.head()
# Out:
#                                        ICME Plasma/Field Start Y/M/D (UT) (b)  \
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                                       1996-05-27 15:00:00
# 1996-07-01 18:00:00                                       1996-07-01 18:00:00
# 1996-08-07 12:00:00                                       1996-08-07 12:00:00
# 1996-12-23 17:00:00                                       1996-12-23 17:00:00
# 1997-01-10 04:00:00                                       1997-01-10 04:00:00
#
#                                        ICME Plasma/Field End Y/M/D (UT) (b)  \
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                                     1996-05-29 03:00:00
# 1996-07-01 18:00:00                                     1996-07-02 11:00:00
# 1996-08-07 12:00:00                                     1996-08-08 10:00:00
# 1996-12-23 17:00:00                                     1996-12-25 11:00:00
# 1997-01-10 04:00:00                                     1997-01-11 02:00:00
#
#                                         BDE? (e)  Qual. (g)  dV (km/s) (h)  \
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                            1          2              1
# 1996-07-01 18:00:00                            1          4             44
# 1996-08-07 12:00:00                            1          2              2
# 1996-12-23 17:00:00                            1          2             22
# 1997-01-10 04:00:00                            3          1              4
#
#                                         V_ICME (km/s) (i)  V_max (km/s) (j)  \
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                                   370               400
# 1996-07-01 18:00:00                                   360               370
# 1996-08-07 12:00:00                                   350               380
# 1996-12-23 17:00:00                                   360               420
# 1997-01-10 04:00:00                                   450               460
#
#                                         B (nT) (k)  MC? (l)  Dst (nT) (m)  \
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                              9        3           117
# 1996-07-01 18:00:00                             11        3            78
# 1996-08-07 12:00:00                              7        3            88
# 1996-12-23 17:00:00                             10        3            69
# 1997-01-10 04:00:00                             14        3           191
#
#                                         Normalized_time_interval
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                                     1.375000
# 1996-07-01 18:00:00                                     0.583333
# 1996-08-07 12:00:00                                     0.791667
# 1996-12-23 17:00:00                                     1.625000
# 1997-01-10 04:00:00                                     0.791667

# %%
df.plot(figsize=(20,6))

# %%
df.columns
# Out:
# Index(['ICME Plasma/Field Start Y/M/D (UT) (b)',
#        'ICME Plasma/Field End Y/M/D (UT) (b)', 'BDE? (e)', 'Qual. (g)',
#        'dV (km/s) (h)', 'V_ICME (km/s) (i)', 'V_max (km/s) (j)', 'B (nT) (k)',
#        'MC? (l)', 'Dst (nT) (m)', 'Normalized_time_interval'],
#       dtype='object')

# %%
keep_cols = ['ICME Plasma/Field Start Y/M/D (UT) (b)', 'BDE? (e)', 'Qual. (g)',
       'dV (km/s) (h)', 'V_ICME (km/s) (i)', 'B (nT) (k)',
       'MC? (l)', 'Dst (nT) (m)', 'Normalized_time_interval']
df = df[keep_cols]
df.head()
# Out:
#                                        ICME Plasma/Field Start Y/M/D (UT) (b)  \
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                                       1996-05-27 15:00:00
# 1996-07-01 18:00:00                                       1996-07-01 18:00:00
# 1996-08-07 12:00:00                                       1996-08-07 12:00:00
# 1996-12-23 17:00:00                                       1996-12-23 17:00:00
# 1997-01-10 04:00:00                                       1997-01-10 04:00:00
#
#                                         BDE? (e)  Qual. (g)  dV (km/s) (h)  \
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                            1          2              1
# 1996-07-01 18:00:00                            1          4             44
# 1996-08-07 12:00:00                            1          2              2
# 1996-12-23 17:00:00                            1          2             22
# 1997-01-10 04:00:00                            3          1              4
#
#                                         V_ICME (km/s) (i)  B (nT) (k)  \
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                                   370           9
# 1996-07-01 18:00:00                                   360          11
# 1996-08-07 12:00:00                                   350           7
# 1996-12-23 17:00:00                                   360          10
# 1997-01-10 04:00:00                                   450          14
#
#                                         MC? (l)  Dst (nT) (m)  \
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                           3           117
# 1996-07-01 18:00:00                           3            78
# 1996-08-07 12:00:00                           3            88
# 1996-12-23 17:00:00                           3            69
# 1997-01-10 04:00:00                           3           191
#
#                                         Normalized_time_interval
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                                     1.375000
# 1996-07-01 18:00:00                                     0.583333
# 1996-08-07 12:00:00                                     0.791667
# 1996-12-23 17:00:00                                     1.625000
# 1997-01-10 04:00:00                                     0.791667

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 493 entries, 1996-05-27 15:00:00 to 2021-05-12 15:00:00
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ICME Plasma/Field Start Y/M/D (UT) (b)  493 non-null    object
#  1   BDE? (e)                                493 non-null    int64
#  2   Qual. (g)                               493 non-null    int64
#  3   dV (km/s) (h)                           493 non-null    int64
#  4   V_ICME (km/s) (i)                       493 non-null    int64
#  5   B (nT) (k)                              493 non-null    int64
#  6   MC? (l)                                 493 non-null    int64
#  7   Dst (nT) (m)                            493 non-null    int64
#  8   Normalized_time_interval                493 non-null    float64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 38.5+ KB

# %% [markdown]
# ## Split the data

# %%
split_fraction = 0.69
train_split = int(split_fraction * int(df.shape[0]))
step = 1

past = 60
future = 1
learning_rate = 0.001
batch_size = 256
epochs = 10

def normalize(data, train_split):
    data_mean = data[:train_split].mean(axis=0)
    data_std = data[:train_split].std(axis=0)
    return (data - data_mean) / data_std

# %%
selected_features = ['BDE? (e)', 'Qual. (g)',
                   'dV (km/s) (h)', 'V_ICME (km/s) (i)', 'B (nT) (k)',
                   'MC? (l)', 'Dst (nT) (m)', 'Normalized_time_interval']

features = df[selected_features]
features.index = df.index

# %%
features.head()
# Out:
#                                         BDE? (e)  Qual. (g)  dV (km/s) (h)  \
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                            1          2              1
# 1996-07-01 18:00:00                            1          4             44
# 1996-08-07 12:00:00                            1          2              2
# 1996-12-23 17:00:00                            1          2             22
# 1997-01-10 04:00:00                            3          1              4
#
#                                         V_ICME (km/s) (i)  B (nT) (k)  \
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                                   370           9
# 1996-07-01 18:00:00                                   360          11
# 1996-08-07 12:00:00                                   350           7
# 1996-12-23 17:00:00                                   360          10
# 1997-01-10 04:00:00                                   450          14
#
#                                         MC? (l)  Dst (nT) (m)  \
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                           3           117
# 1996-07-01 18:00:00                           3            78
# 1996-08-07 12:00:00                           3            88
# 1996-12-23 17:00:00                           3            69
# 1997-01-10 04:00:00                           3           191
#
#                                         Normalized_time_interval
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 1996-05-27 15:00:00                                     1.375000
# 1996-07-01 18:00:00                                     0.583333
# 1996-08-07 12:00:00                                     0.791667
# 1996-12-23 17:00:00                                     1.625000
# 1997-01-10 04:00:00                                     0.791667

# %%
features.shape
# Out:
# (493, 8)

# %%
df.columns
# Out:
# Index(['ICME Plasma/Field Start Y/M/D (UT) (b)', 'BDE? (e)', 'Qual. (g)',
#        'dV (km/s) (h)', 'V_ICME (km/s) (i)', 'B (nT) (k)', 'MC? (l)',
#        'Dst (nT) (m)', 'Normalized_time_interval'],
#       dtype='object')

# %%
titles = ['BDE? (e)', 'Qual. (g)', 'dV (km/s) (h)', 'V_ICME (km/s) (i)',
       'B (nT) (k)', 'MC? (l)', 'Dst (nT) (m)', 'Normalized_time_interval']

feature_keys = ['BDE? (e)', 'Qual. (g)', 'dV (km/s) (h)', 'V_ICME (km/s) (i)',
       'B (nT) (k)', 'MC? (l)', 'Dst (nT) (m)', 'Normalized_time_interval']

colors = [
    "blue",
    "orange",
    "green",
    "red",
    "purple",
    "brown",
    "pink",
    "gray",
]

date_time_key = "ICME Plasma/Field Start Y/M/D (UT) (b)"


def show_raw_visualization(data):
    time_data = data[date_time_key]
    fig, axes = plt.subplots(
        nrows=4, ncols=2, figsize=(15, 20), dpi=80, facecolor="w", edgecolor="k"
    )
    for i in range(len(feature_keys)):
        key = feature_keys[i]
        c = colors[i % (len(colors))]
        t_data = data[key]
        t_data.index = time_data
        t_data.head()
        ax = t_data.plot(
            ax=axes[i // 2, i % 2],
            color=c,
            title="{} - {}".format(titles[i], key),
            rot=25,
        )
        ax.legend([titles[i]])
    plt.tight_layout()


show_raw_visualization(df)

# %% [markdown]
# ## Normalizing data

# %%
features = normalize(features.values, train_split)
features = pd.DataFrame(features)
features.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -1.398798 -0.389291 -1.507188 -0.862626 -0.214904  1.060704  0.043285
# 1 -1.398798  1.275601  0.664612 -0.952263  0.238930  1.060704 -0.605988
# 2 -1.398798 -0.389291 -1.456681 -1.041900 -0.668738  1.060704 -0.439508
# 3 -1.398798 -0.389291 -0.446541 -0.952263  0.012013  1.060704 -0.755820
# 4  0.724378 -1.221737 -1.355667 -0.145529  0.919682  1.060704  1.275238
#
#           7
# 0  0.499631
# 1 -0.717190
# 2 -0.396974
# 3  0.883890
# 4 -0.396974

# %%
features.shape
# Out:
# (493, 8)

# %% [markdown]
# ## Train and Val

# %%
train_data = features.loc[0 : train_split - 1]
val_data = features.loc[train_split:]

# %%
train_data.shape
# Out:
# (340, 8)

# %%
val_data.shape
# Out:
# (153, 8)

# %%
train_data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -1.398798 -0.389291 -1.507188 -0.862626 -0.214904  1.060704  0.043285
# 1 -1.398798  1.275601  0.664612 -0.952263  0.238930  1.060704 -0.605988
# 2 -1.398798 -0.389291 -1.456681 -1.041900 -0.668738  1.060704 -0.439508
# 3 -1.398798 -0.389291 -0.446541 -0.952263  0.012013  1.060704 -0.755820
# 4  0.724378 -1.221737 -1.355667 -0.145529  0.919682  1.060704  1.275238
#
#           7
# 0  0.499631
# 1 -0.717190
# 2 -0.396974
# 3  0.883890
# 4 -0.396974

# %%
start = past + future
end = start + train_split
print('start = ', start)
print('end = ', end)
print('train_split = ', train_split)
sequence_length = int(past / step)
print('sequence_length = ', sequence_length)
# Out:
# start =  61
# end =  401
# train_split =  340
# sequence_length =  60

# %% [markdown]
# ## Choose target column

# %%
features.iloc[start:end][[3]]
# Out:
#             3
# 61  -1.041900
# 62  -0.414440
# 63   0.930117
# 64  -0.235166
# 65  -0.055891
# ..        ...
# 396 -0.055891
# 397 -0.145529
# 398 -0.055891
# 399 -1.490086
# 400 -0.862626
#
# [340 rows x 1 columns]

# %%
x_train = train_data[[i for i in range(7)]].values
y_train = features.iloc[start:end][[3]]

# %%
y_train.plot()

# %%
len(x_train)
# Out:
# 340

# %%
print('x_train.shape', x_train.shape,
      '\ny_train.shape', y_train.shape)
# Out:
# x_train.shape (340, 7)
# y_train.shape (340, 1)

# %% [markdown]
# ## Preprocessing data

# %%
dataset_train = keras.preprocessing.timeseries_dataset_from_array(x_train,
                                                                  y_train,
                                                                  sequence_length=sequence_length,
                                                                  sampling_rate=step,
                                                                  batch_size=batch_size,
                                                                  )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-69d0eebab125> in <module>()
# ----> 1 dataset_train = keras.preprocessing.timeseries_dataset_from_array(x_train,
#       2                                                                   y_train,
#       3                                                                   sequence_length=sequence_length,
#       4                                                                   sampling_rate=step,
#       5                                                                   batch_size=batch_size,
#
# AttributeError: module 'tensorflow._api.v1.keras.preprocessing' has no attribute 'timeseries_dataset_from_array'

# %%
# dataset_train
# print(val_data)

# %%
x_end = len(val_data) - past - future
# print('x_end ', x_end)
label_start = train_split + past + future
# print('label_start ', label_start)

# %%
x_val = val_data.iloc[:x_end][[i for i in range(7)]].values
y_val = features.iloc[label_start:][[3]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-f18cb2b74f80> in <module>()
# ----> 1 x_val = val_data.iloc[:x_end][[i for i in range(7)]].values
#       2 y_val = features.iloc[label_start:][[3]]
#
# NameError: name 'x_end' is not defined

# %%
y_val.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-1599d4b2a56b> in <module>()
# ----> 1 y_val.plot()
#
# NameError: name 'y_val' is not defined

# %%
# train_split
# x_val.shape
# y_val.shape
# sequence_length
# batch_size
# step

# %%
dataset_val = keras.preprocessing.timeseries_dataset_from_array(x_val,
                                                                y_val,
                                                                sequence_length=sequence_length,
                                                                sampling_rate=step,
                                                                batch_size=batch_size,
                                                                )


for batch in dataset_train.take(1):
    inputs, targets = batch

# print("Input shape:", inputs.numpy().shape)
# print("Target shape:", targets.numpy().shape)


print("Input shape:", inputs.shape)
print("Target shape:", targets.shape)
# Out:
# Input shape: (256, 60, 7)
# Target shape: (256, 1)
# 2021-10-27 17:26:43.585811: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %% [markdown]
# ## Assemble keras model

# %%
inputs = keras.layers.Input(shape=(inputs.shape[1], 
                                   inputs.shape[2]))

lstm_out = keras.layers.LSTM(8)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), 
              loss="mse")

model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/y0/960g9wv95_j3h357d8zwrxy00000gn/T/ipykernel_49992/1917477173.py in <module>
# ----> 1 inputs = keras.layers.Input(shape=(inputs.shape[1],
#       2                                    inputs.shape[2]))
#       3
#       4 lstm_out = keras.layers.LSTM(8)(inputs)
#       5 outputs = keras.layers.Dense(1)(lstm_out)
#
# NameError: name 'keras' is not defined

# %% [markdown]
# ## Fit the model

# %%
path_checkpoint = "../Models/LSTM_Multivariate_P03_05.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", 
                                            min_delta=0, 
                                            patience=5)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
                                                    monitor="val_loss",
                                                    filepath=path_checkpoint,
                                                    verbose=1,
                                                    #save_weights_only=True,
                                                    save_best_only=True,
                                                )

history = model.fit(
                    dataset_train,
                    epochs=20,
                    validation_data=dataset_val,
                    shuffle=False,
                    callbacks=[modelckpt_callback],#es_callback, 
                )
# Out:
# Epoch 1/20
# 2/2 [==============================] - 2s 444ms/step - loss: 0.6997 - val_loss: 0.4851
#
# Epoch 00001: val_loss improved from inf to 0.48508, saving model to ../Models/LSTM_Multivariate_P03_05.h5
# Epoch 2/20
# 2/2 [==============================] - 0s 88ms/step - loss: 0.6863 - val_loss: 0.4854
#
# Epoch 00002: val_loss did not improve from 0.48508
# Epoch 3/20
# 2/2 [==============================] - 0s 94ms/step - loss: 0.6789 - val_loss: 0.4860
#
# Epoch 00003: val_loss did not improve from 0.48508
# Epoch 4/20
# 2/2 [==============================] - 0s 88ms/step - loss: 0.6760 - val_loss: 0.4865
#
# Epoch 00004: val_loss did not improve from 0.48508
# Epoch 5/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.6677 - val_loss: 0.4876
#
# Epoch 00005: val_loss did not improve from 0.48508
# Epoch 6/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.6566 - val_loss: 0.4886
#
# Epoch 00006: val_loss did not improve from 0.48508
# Epoch 7/20
# 2/2 [==============================] - 0s 90ms/step - loss: 0.6435 - val_loss: 0.4893
#
# Epoch 00007: val_loss did not improve from 0.48508
# Epoch 8/20
# 2/2 [==============================] - 0s 88ms/step - loss: 0.6382 - val_loss: 0.4899
#
# Epoch 00008: val_loss did not improve from 0.48508
# Epoch 9/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.6382 - val_loss: 0.4899
#
# Epoch 00009: val_loss did not improve from 0.48508
# Epoch 10/20
# 2/2 [==============================] - 0s 86ms/step - loss: 0.6264 - val_loss: 0.4906
#
# Epoch 00010: val_loss did not improve from 0.48508
# Epoch 11/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.6163 - val_loss: 0.4912
#
# Epoch 00011: val_loss did not improve from 0.48508
# Epoch 12/20
# 2/2 [==============================] - 0s 86ms/step - loss: 0.6028 - val_loss: 0.4918
#
# Epoch 00012: val_loss did not improve from 0.48508
# Epoch 13/20
# 2/2 [==============================] - 0s 92ms/step - loss: 0.5948 - val_loss: 0.4924
#
# Epoch 00013: val_loss did not improve from 0.48508
# Epoch 14/20
# 2/2 [==============================] - 0s 89ms/step - loss: 0.5926 - val_loss: 0.4926
#
# Epoch 00014: val_loss did not improve from 0.48508
# Epoch 15/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.6074 - val_loss: 0.4944
#
# Epoch 00015: val_loss did not improve from 0.48508
# Epoch 16/20
# 2/2 [==============================] - 0s 92ms/step - loss: 0.6710 - val_loss: 0.4950
#
# Epoch 00016: val_loss did not improve from 0.48508
# Epoch 17/20
# 2/2 [==============================] - 0s 89ms/step - loss: 0.5851 - val_loss: 0.4947
#
# Epoch 00017: val_loss did not improve from 0.48508
# Epoch 18/20
# 2/2 [==============================] - 0s 87ms/step - loss: 0.6635 - val_loss: 0.4952
#
# Epoch 00018: val_loss did not improve from 0.48508
# Epoch 19/20
# 2/2 [==============================] - 0s 87ms/step - loss: 0.5764 - val_loss: 0.4958
#
# Epoch 00019: val_loss did not improve from 0.48508
# Epoch 20/20
# 2/2 [==============================] - 0s 91ms/step - loss: 0.6158 - val_loss: 0.4963
#
# Epoch 00020: val_loss did not improve from 0.48508

# %% [markdown]
# ## Load the pre-trained model

# %%
from tensorflow.keras.models import *

# %%
path_1 = '../Models/LSTM_Multivariate_P03_05.h5'
model = keras.models.load_model(path_1)

# %%
def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()


visualize_loss(history, "Training and Validation Loss")

# %%
def show_plot(plot_data, delta, title):
    plt.figure(figsize=(20,8))
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
            
            
    plt.legend()
    plt.xlim([time_steps[0], (future + 5) * 2])
    plt.xlabel("Time-Step")
#     plt.show()
    
    return

# %% [markdown]
# ## GIF

# %%
@gif.frame
def plott(i):
    real_values = []
    predited_values = []

    for x, y in dataset_val.take(-1):



#         for i in range(1,33):
#             print(i)
        show_plot(
            [x[i][:, 3].numpy(), y[i].numpy(), model.predict(x)[i]],
            1,
            "Single Step Prediction",
        )

        real_values.append(y[i].numpy())
        predited_values.append(model.predict(x)[i])

# %%
plott(1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1440x576 at 0x7FD0593990F0>

# %%
frames = []    
for i in tqdm(range(1,33)):

    
    frame = plott(i)
    frames.append(frame)
# Out:
# 100%|███████████████████████████████████████████| 32/32 [00:09<00:00,  3.27it/s]

# %%
gif.save(frames, "../Figures/LSTM_multi_P3_5.gif", duration=2)

# %% [markdown]
# <p align="center">
#   <img width="1200" src="../Figures/LSTM_multi_P3_5.gif" >
# </p>

# %%
from sklearn.metrics import r2_score

coefficient_of_dermination = r2_score(real_values, predited_values)
coefficient_of_dermination
# Out:
# -0.00684391665555828

# %%
rs2 = round(coefficient_of_dermination,2)
rs2
# Out:
# -0.01

# %%
plt.figure(figsize=(10,10))

plt.scatter(real_values, predited_values, color='r', 
            alpha=0.4, label=f'Validation Data with R2 = {rs2}',s=100)
plt.xlabel("Normalized Real Temperature", fontsize=14)
plt.ylabel("Normalized Predited Temperature", fontsize=14)
plt.xticks(fontsize=12), plt.yticks(fontsize=12)
plt.axline([0, 0], [1, 1], color ='k')
plt.hlines(0, -4, 4, linestyles="--", color ='k')
plt.vlines(0, -4, 4, linestyles="--", color ='k')

plt.xlim(-3,3), plt.ylim(-3,3)

plt.title("LSTM model Temperature forcast results for 12 \
hours ahead\nData from 120 hours lags is used for prediction", fontsize=14)

plt.tight_layout()
plt.legend(fontsize=14)

# plt.savefig("../Figures/" + section_fig_main_title + "LSTM12HoursAhead.png")
