# %% [markdown]
# # Supervise_Project

# %%
section_fig_main_title = 'Supervise_Project_'

# %%
import os, sys
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup as bs
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
from pandas.plotting import lag_plot
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import LocalOutlierFactor
from sklearn.metrics import mean_absolute_error

# %%
from numpy import mean
import numpy as np
from numpy import absolute
from numpy import loadtxt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.pipeline import Pipeline
from sklearn.linear_model import HuberRegressor
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import TransformedTargetRegressor

# %%
from pandas.plotting import autocorrelation_plot
from sklearn.feature_selection import VarianceThreshold

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %%
from sklearn import metrics
import statsmodels.api as sm

# %% [markdown]
# ## Read Data
#
# the page html file downloaded in Data directory and it is loaded below.

# %%
# csv_path = "../Data/Data_ICME_scraped.csv"
# data = pd.read_csv(csv_path, parse_dates=True)

csv_path = "../Data/P02_05_EDA_Data.csv"
data = pd.read_csv(csv_path, parse_dates=True, infer_datetime_format=True)

# %%
data.head(2)
# Out:
#   ICME Plasma/Field Start Y/M/D (UT) (b)  \
# 0                    1996-05-27 15:00:00
# 1                    1996-07-01 18:00:00
#
#   Evidence of BiDirectional suprathermal Electron strahls (BDE)  \
# 0                                                  N
# 1                                                  N
#
#   "quality" of the boundary times  \
# 0                               2
# 1                               3
#
#   Increase in solar wind speed at the upstream disturbance (shock/wave)  \
# 0                                                  0
# 1                                                 40
#
#    solar wind speed km/s  Mean magnetic field strength in the ICME  \
# 0                    370                                         9
# 1                    360                                        11
#
#   magnetic cloud has been reported minimum value of the geomagnetic  \
# 0                                2                              -33
# 1                                2                              -20
#
#   Mean 1 AU transit speed of the disturbance forward fast shock happens  \
# 0                                        ...                         No
# 1                                        ...                         No
#
#    "quality" of the boundary times*  \
# 0                               2.0
# 1                               3.0
#
#   Evidence of BiDirectional suprathermal Electron strahls (BDE)*  \
# 0                                        no Evidence
# 1                                        no Evidence
#
#    Increase in solar wind speed at the upstream disturbance (shock/wave)*  \
# 0                                                  0
# 1                                                 40
#
#   magnetic cloud has been reported*  minimum value of the geomagnetic*  \
# 0  magnetic cloud has been reported                                -33
# 1  magnetic cloud has been reported                                -20
#
#    Mean 1 AU transit speed of the disturbance*
# 0                                            0
# 1                                            0

# %%
keep_cols = ['ICME Plasma/Field Start Y/M/D (UT) (b)',
             'solar wind speed km/s',
       'forward fast shock happens', '"quality" of the boundary times*',
       'Evidence of BiDirectional suprathermal Electron strahls (BDE)*',
       'Increase in solar wind speed at the upstream disturbance (shock/wave)*',
       'magnetic cloud has been reported*',
       'minimum value of the geomagnetic*',
       'Mean 1 AU transit speed of the disturbance*']
data = data[keep_cols]

# %%
data.head()
# Out:
#   ICME Plasma/Field Start Y/M/D (UT) (b)  solar wind speed km/s  \
# 0                    1996-05-27 15:00:00                    370
# 1                    1996-07-01 18:00:00                    360
# 2                    1996-08-07 12:00:00                    350
# 3                    1996-12-23 17:00:00                    360
# 4                    1997-01-10 04:00:00                    450
#
#   forward fast shock happens  "quality" of the boundary times*  \
# 0                         No                               2.0
# 1                         No                               3.0
# 2                         No                               2.0
# 3                         No                               2.0
# 4                        Yes                               1.0
#
#   Evidence of BiDirectional suprathermal Electron strahls (BDE)*  \
# 0                                        no Evidence
# 1                                        no Evidence
# 2                                        no Evidence
# 3                                        no Evidence
# 4                                      some Evidence
#
#    Increase in solar wind speed at the upstream disturbance (shock/wave)*  \
# 0                                                  0
# 1                                                 40
# 2                                                 10
# 3                                                 20
# 4                                                100
#
#   magnetic cloud has been reported*  minimum value of the geomagnetic*  \
# 0  magnetic cloud has been reported                                -33
# 1  magnetic cloud has been reported                                -20
# 2  magnetic cloud has been reported                                -23
# 3  magnetic cloud has been reported                                -18
# 4  magnetic cloud has been reported                                -78
#
#    Mean 1 AU transit speed of the disturbance*
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                          435
# 4                                          507

# %%
for col in data.columns:
    if col != 'ICME Plasma/Field Start Y/M/D (UT) (b)':
        print(f'{col} = ', data[col].nunique(),'\n')
        print(f'{col} = ', data[col].unique(), '\n\n')
# Out:
# solar wind speed km/s =  51
#
# solar wind speed km/s =  [ 370  360  350  450  460  340  380  400  390  410  440  430  500  510
#   530  320  520  550  470  650  420  640  570  540  490  670  620  480
#   560  610  780  740  580  600  790  290  730  330  720  590  680 1300
#   800  870  630  810  900  750  310  660  300]
#
#
# forward fast shock happens =  2
#
# forward fast shock happens =  ['No' 'Yes']
#
#
# "quality" of the boundary times* =  5
#
# "quality" of the boundary times* =  [2.  3.  1.  2.5 3.5]
#
#
# Evidence of BiDirectional suprathermal Electron strahls (BDE)* =  3
#
# Evidence of BiDirectional suprathermal Electron strahls (BDE)* =  ['no Evidence' 'some Evidence' nan
#  'intense solar energetic particle event was in progress at the time of ICME passage and electron flows therefore cannot be determined']
#
#
# Increase in solar wind speed at the upstream disturbance (shock/wave)* =  38
#
# Increase in solar wind speed at the upstream disturbance (shock/wave)* =  [  0  40  10  20 100  90 150  70  30  60  80 110 140 170  50 250 200 300
#  130 120 180 280 220 260 350 230 400 550 160 210 650 340 900 750 240 320
#  270 190]
#
#
# magnetic cloud has been reported* =  4
#
# magnetic cloud has been reported* =  ['magnetic cloud has been reported'
#  'magnetic cloud has been reported&\nevent reported by Huttunen et al. Ann Geophys'
#  'magnetic cloud has not been reported'
#  'evidence of a rotation in field direction, but lacks some other characteristics of a magnetic cloud']
#
#
# minimum value of the geomagnetic* =  159
#
# minimum value of the geomagnetic* =  [ -33  -20  -23  -18  -78  -68  -82 -107 -115  -74  -84  -36  -45  -48
#   -28  -98  -64 -130  -60 -110 -108  -47  -77  -29  -11  -55  -34 -100
#   -51  -56  -35  -46  -85 -205   -1  -25 -101  -30   -6 -138  -62  -27
#   -19  -67 -155 -207 -112  -52  -81 -149 -131  -15  -58  -17   -7 -123
#   -91  -13  -41  -26   -4  -38  -39  -16  -66 -173 -237  -69 -106   -8
#   -97 -133  -43   -3 -288  -14  -61  -37  -10   -2  -32  -92 -147  -90
#   -12  -76    0  -57 -301  -93  -42  -71 -235 -201 -143 -182 -127 -159
#   -80 -119  -73  -87 -387  -50  -59 -271 -114 -102 -105  -40  -24 -148
#  -104 -166 -187 -157 -292 -221 -109  -21 -181 -176 -146  -75  -72  -49
#  -144  -63 -141 -353 -383 -422 -117  -99 -136 -170 -129 -374 -263  -65
#  -247  -83 -113 -139  -88  -86  -22  -79 -162  -31   -5 -118 -145 -120
#  -122    1    9 -132  -95]
#
#
# Mean 1 AU transit speed of the disturbance* =  122
#
# Mean 1 AU transit speed of the disturbance* =  [   0  435  507  683  552  616  381  410  405  450  580  430  572  640
#   460  480  557  602  440  780 1150 1260 1020  510  570  740  520  870
#   760  620  560  710  615  770  561  530  630  915  815  860  603  500
#   830  650  403 1007  609  940 1500  490  550  418  756  590  565  660
#  1200  720  380  680  610  850  690  700 1050 1290  990 1040  790  715
#   417  694 1250 1320  667  625  750  863  420 1323  955  766  880  910
#   820  999 1078 1331 2185 2138  886  920  890 1302  960 1080 1170 1210
#  1270  488  477  840 1423  540 1180  980  437  350  400  600  360  670
#  1100 1220  370  730  470  563  800  810  330  300]

# %%
data.columns
# Out:
# Index(['ICME Plasma/Field Start Y/M/D (UT) (b)', 'solar wind speed km/s',
#        'forward fast shock happens', '"quality" of the boundary times*',
#        'Evidence of BiDirectional suprathermal Electron strahls (BDE)*',
#        'Increase in solar wind speed at the upstream disturbance (shock/wave)*',
#        'magnetic cloud has been reported*',
#        'minimum value of the geomagnetic*',
#        'Mean 1 AU transit speed of the disturbance*'],
#       dtype='object')

# %% [markdown]
# # Remove Missing Values

# %%
cols = ['solar wind speed km/s',
       'Evidence of BiDirectional suprathermal Electron strahls (BDE)*',
       'Increase in solar wind speed at the upstream disturbance (shock/wave)*',
       'minimum value of the geomagnetic*',
#        'Mean 1 AU transit speed of the disturbance*',
       ]

# summarize the shape of the raw data
print(data.shape)
# replace '0' values with 'nan'
data[cols] = data[cols].replace(0, np.nan)
# drop rows with missing values
data.dropna(inplace=True)
# summarize the shape of the data with missing rows removed
print(data.shape)
# Out:
# (513, 9)
# (371, 9)

# %% [markdown]
# # Check out data for duplicates

# %%
# calculate duplicates
dups = data.duplicated()
# report if there are any duplicates
print(dups.any())
# list all duplicate rows
print(data[dups])
# Out:
# False
# Empty DataFrame
# Columns: [ICME Plasma/Field Start Y/M/D (UT) (b), solar wind speed km/s, forward fast shock happens, "quality" of the boundary times*, Evidence of BiDirectional suprathermal Electron strahls (BDE)*, Increase in solar wind speed at the upstream disturbance (shock/wave)*, magnetic cloud has been reported*, minimum value of the geomagnetic*, Mean 1 AU transit speed of the disturbance*]
# Index: []

# %% [markdown]
# No duplicate exist in data set

# %%
print(data.shape)
# delete duplicate rows
data.drop_duplicates(inplace=True)
print(data.shape)
# Out:
# (371, 9)
# (371, 9)

# %% [markdown]
# # Check out columns unique values percentage

# %%
uniq_index = list(data.nunique().index)
uniq_values = list(data.nunique())
num_rows = data.shape[0]

uniq_percent = [(val*100)/num_rows for val in uniq_values]
for i, uniq in enumerate(uniq_percent):
    print(uniq_index[i])
    print(round(uniq, 2))
# Out:
# ICME Plasma/Field Start Y/M/D (UT) (b)
# 100.0
# solar wind speed km/s
# 13.48
# forward fast shock happens
# 0.54
# "quality" of the boundary times*
# 1.35
# Evidence of BiDirectional suprathermal Electron strahls (BDE)*
# 0.81
# Increase in solar wind speed at the upstream disturbance (shock/wave)*
# 9.7
# magnetic cloud has been reported*
# 1.08
# minimum value of the geomagnetic*
# 41.78
# Mean 1 AU transit speed of the disturbance*
# 30.73

# %% [markdown]
# # Data distribution
#
# checking out the data skewness and distribution

# %%
data.head()
# Out:
#   ICME Plasma/Field Start Y/M/D (UT) (b)  solar wind speed km/s  \
# 1                    1996-07-01 18:00:00                    360
# 2                    1996-08-07 12:00:00                    350
# 3                    1996-12-23 17:00:00                    360
# 4                    1997-01-10 04:00:00                    450
# 5                    1997-02-10 02:00:00                    450
#
#   forward fast shock happens  "quality" of the boundary times*  \
# 1                         No                               3.0
# 2                         No                               2.0
# 3                         No                               2.0
# 4                        Yes                               1.0
# 5                        Yes                               2.0
#
#   Evidence of BiDirectional suprathermal Electron strahls (BDE)*  \
# 1                                        no Evidence
# 2                                        no Evidence
# 3                                        no Evidence
# 4                                      some Evidence
# 5                                      some Evidence
#
#    Increase in solar wind speed at the upstream disturbance (shock/wave)*  \
# 1                                               40.0
# 2                                               10.0
# 3                                               20.0
# 4                                              100.0
# 5                                               90.0
#
#   magnetic cloud has been reported*  minimum value of the geomagnetic*  \
# 1  magnetic cloud has been reported                              -20.0
# 2  magnetic cloud has been reported                              -23.0
# 3  magnetic cloud has been reported                              -18.0
# 4  magnetic cloud has been reported                              -78.0
# 5  magnetic cloud has been reported                              -68.0
#
#    Mean 1 AU transit speed of the disturbance*
# 1                                            0
# 2                                            0
# 3                                          435
# 4                                          507
# 5                                          683

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371 entries, 1 to 438
# Data columns (total 9 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   ICME Plasma/Field Start Y/M/D (UT) (b)                                  371 non-null    object
#  1   solar wind speed km/s                                                   371 non-null    int64
#  2   forward fast shock happens                                              371 non-null    object
#  3   "quality" of the boundary times*                                        371 non-null    float64
#  4   Evidence of BiDirectional suprathermal Electron strahls (BDE)*          371 non-null    object
#  5   Increase in solar wind speed at the upstream disturbance (shock/wave)*  371 non-null    float64
#  6   magnetic cloud has been reported*                                       371 non-null    object
#  7   minimum value of the geomagnetic*                                       371 non-null    float64
#  8   Mean 1 AU transit speed of the disturbance*                             371 non-null    int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 29.0+ KB

# %%
data.hist(bins=20, 
            figsize=(10,8), 
            log=True,
           )

plt.tight_layout()
plt.show()

# %% [markdown]
# data distribution is skewed and is semi gaussian

# %% [markdown]
# # Automatic Outlier Detection using Local Outlier Factor (LOF)

# %%
cols_trans = [
                'solar wind speed km/s', 
                '"quality" of the boundary times*',
                'Increase in solar wind speed at the upstream disturbance (shock/wave)*',
                'minimum value of the geomagnetic*',
                'Mean 1 AU transit speed of the disturbance*'
            ]
data_3 = data[cols_trans]

# %% [markdown]
# # Train Test split
#
#
# applying LOF on train set (67%).

# %%
# split into inpiut and output elements
X = data_3.drop(['solar wind speed km/s'], axis=1)
y = data_3['solar wind speed km/s']

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# summarize the shape of the training dataset
print(X_train.shape, y_train.shape)
# Out:
# (248, 4) (248,)

# %% [markdown]
# # LOF on Training data

# %%
# identify outliers in the training dataset
lof = LocalOutlierFactor()
yhat = lof.fit_predict(X_train)

# select all rows that are not outliers
mask = yhat != -1
X_train, y_train = X_train.iloc[mask, :], y_train.iloc[mask]

# summarize the shape of the updated training dataset
print(X_train.shape, y_train.shape)
# Out:
# (223, 4) (223,)

# %%
X_train.hist(bins=20, 
            figsize=(10,8), 
            log=True,
           )

plt.tight_layout()
plt.show()

# %%
y_train.hist(bins=20, 
#             figsize=(10,8), 
#             log=True,
           )

plt.tight_layout()
plt.show()

# %% [markdown]
# No need to apply LOF on test, Just follow the steps and use model to predict at the end.

# %% [markdown]
# # MiniMax transformer and features selection base on variance

# %%
steps = list()
steps.append(('scale', MinMaxScaler(feature_range=(1e-5,1))))
pipeline = Pipeline(steps=steps)
X_train_trans_np = pipeline.fit_transform(X_train,y_train)

# %%
X_train_trans_df = pd.DataFrame(X_train_trans_np)
X_train_trans_df.hist(bins=20, 
            figsize=(10,8), 
            log=True,
           )

plt.tight_layout()
plt.show()

# %% [markdown]
# checking out the features variances and drop them based on the column variances.

# %%
# define thresholds to check
thresholds = np.arange(0.0, 0.09, 0.01)
# apply transform with each threshold
results = list()
for t in thresholds:
    # define the transform
    transform = VarianceThreshold(threshold=t)
    # transform the input data
    X_sel = transform.fit_transform(X_train_trans_df)
    # determine the number of input features
    n_features = X_sel.shape[1]
    print('>Threshold=%.2f, Features=%d' % (t, n_features))
    # store the result
    results.append(n_features)
# plot the threshold vs the number of selected features
plt.plot(thresholds, results, 'ro-')
plt.xlabel('VarianceThreshold')
plt.ylabel('Number of features')
plt.ylim(0,5)
plt.show()
# Out:
# >Threshold=0.00, Features=4
# >Threshold=0.01, Features=4
# >Threshold=0.02, Features=4
# >Threshold=0.03, Features=4
# >Threshold=0.04, Features=2
# >Threshold=0.05, Features=2
# >Threshold=0.06, Features=2
# >Threshold=0.07, Features=2
# >Threshold=0.08, Features=2

# %% [markdown]
# I decided not to proceed with the features selection based on the feature variance.

# %% [markdown]
# # MinMax & PowerTransformer on training data
#
# Transfer columns to gaussian or more gaussian distribution

# %%
# prepare the model with input scaling and power transform
steps = list()
steps.append(('scale', MinMaxScaler(feature_range=(1e-5,1))))
steps.append(('power', PowerTransformer()))
pipeline = Pipeline(steps=steps)
trans_np = pipeline.fit_transform(X_train,y_train)

# %%
trans_df = pd.DataFrame(trans_np)

trans_df.hist(bins=20, 
            figsize=(10,8), 
            log=True,
           )

plt.tight_layout()
plt.show()

# %% [markdown]
# # MinMaxScaler, PowerTransformer & HuberRegressor on training data

# %%
steps = list()
steps.append(('scale', MinMaxScaler(feature_range=(1e-5,1))))
steps.append(('power', PowerTransformer()))
steps.append(('model', HuberRegressor()))
pipeline = Pipeline(steps=steps)

# %%
# prepare the model with target scaling
model = TransformedTargetRegressor(regressor=pipeline)

# evaluate model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
scores = cross_val_score(model, X_train, y_train, 
                         scoring='neg_mean_absolute_error', 
                         cv=cv, n_jobs=-1)

# convert scores to positive
scores = absolute(scores)
# summarize the result
s_mean = mean(scores)
print('Mean MAE: %.3f' % (s_mean))
# Out:
# Mean MAE: 57.149

# %%
plt.boxplot(scores, vert=False)
plt.xlim(0, )
plt.xlabel('MAE')
plt.show()

# %% [markdown]
# # Fit and Predict with whole pipeline
#
# Note that the LOF was applied already on train set (fit) and no need to apply LOF on test.

# %%
steps = list()
steps.append(('scale', MinMaxScaler(feature_range=(1e-5,1))))
steps.append(('power', PowerTransformer()))
steps.append(('model', HuberRegressor(max_iter=150)))
pipeline = Pipeline(steps=steps)

# %%
# fit pipeline
pipeline.fit(X_train, y_train)
# make predictions
yhat = pipeline.predict(X_test)

# %%
plt.figure(figsize=(8,8))
plt.scatter(yhat, y_test)
plt.ylabel('prediction - solar wind speed km/s')
plt.xlabel('data - solar wind speed km/s')
plt.axline([0, 0], [800, 800], color ='k')
plt.xlim(0, 800)
plt.ylim(0, 800)
plt.show()

# %%
print('r2_score ', r2_score(yhat, y_test))
print('mean_absolute_error ', mean_absolute_error(yhat, y_test))
# Out:
# r2_score  -0.13975396795702455
# mean_absolute_error  50.25320648218336

# %%
from sklearn.metrics import explained_variance_score
from sklearn.neural_network import MLPRegressor

# %%
from sklearn.linear_model import LinearRegression, Perceptron, Lasso

# %%
def Apply_models(model, model_name):

    steps = list()
    steps.append(('scale', MinMaxScaler(feature_range=(1e-5,1))))
    steps.append(('power', PowerTransformer()))
    steps.append(('model', model()))
    pipeline = Pipeline(steps=steps)


    # fit pipeline
    pipeline.fit(X_train, y_train)
    # make predictions
    yhat = pipeline.predict(X_test)


#     plt.figure(figsize=(8,8))
#     plt.scatter(yhat, y_test)
#     plt.ylabel('prediction - solar wind speed km/s')
#     plt.xlabel('data - solar wind speed km/s')
#     plt.axline([0, 0], [800, 800], color ='k')
#     plt.xlim(0, 800)
#     plt.ylim(0, 800)
#     plt.show()
    print(model_name)
    print('r2_score ', r2_score(yhat, y_test))
    print('mean_absolute_error ', mean_absolute_error(yhat, y_test))
    print('explained_variance_score ', explained_variance_score(yhat, y_test))

# %%
model_list = [LinearRegression, Perceptron, Lasso, MLPRegressor]
model_name_list = ['LinearRegression', 'Perceptron', 'Lasso', 'MLPRegressor']
for i, model in enumerate(model_list):
    Apply_models(model, model_name_list[i])
    print(50*'+')
# Out:
# LinearRegression
# r2_score  0.034381436478780336
# mean_absolute_error  52.09025287006257
# explained_variance_score  0.044417401288572855
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Perceptron
# r2_score  0.08536970278902101
# mean_absolute_error  78.3739837398374
# explained_variance_score  0.0885042222896748
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Lasso
# r2_score  0.0022104366940056686
# mean_absolute_error  51.76795044490605
# explained_variance_score  0.01372769245251193
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# MLPRegressor
# r2_score  -715.6870653111512
# mean_absolute_error  410.22967232444694
# explained_variance_score  -24.219815718138946
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # Categorical features selection
#
#
# select catogorical features

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371 entries, 1 to 438
# Data columns (total 9 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   ICME Plasma/Field Start Y/M/D (UT) (b)                                  371 non-null    object
#  1   solar wind speed km/s                                                   371 non-null    int64
#  2   forward fast shock happens                                              371 non-null    object
#  3   "quality" of the boundary times*                                        371 non-null    float64
#  4   Evidence of BiDirectional suprathermal Electron strahls (BDE)*          371 non-null    object
#  5   Increase in solar wind speed at the upstream disturbance (shock/wave)*  371 non-null    float64
#  6   magnetic cloud has been reported*                                       371 non-null    object
#  7   minimum value of the geomagnetic*                                       371 non-null    float64
#  8   Mean 1 AU transit speed of the disturbance*                             371 non-null    int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 29.0+ KB

# %%
catogorical_features = data.select_dtypes('object')

# %%
catogorical_features.head(2)
# Out:
#   ICME Plasma/Field Start Y/M/D (UT) (b) forward fast shock happens  \
# 1                    1996-07-01 18:00:00                         No
# 2                    1996-08-07 12:00:00                         No
#
#   Evidence of BiDirectional suprathermal Electron strahls (BDE)*  \
# 1                                        no Evidence
# 2                                        no Evidence
#
#   magnetic cloud has been reported*
# 1  magnetic cloud has been reported
# 2  magnetic cloud has been reported

# %%
catogorical_data = pd.concat([catogorical_features, data['solar wind speed km/s']], axis=1)

# %%
catogorical_data.head(2)
# Out:
#   ICME Plasma/Field Start Y/M/D (UT) (b) forward fast shock happens  \
# 1                    1996-07-01 18:00:00                         No
# 2                    1996-08-07 12:00:00                         No
#
#   Evidence of BiDirectional suprathermal Electron strahls (BDE)*  \
# 1                                        no Evidence
# 2                                        no Evidence
#
#   magnetic cloud has been reported*  solar wind speed km/s
# 1  magnetic cloud has been reported                    360
# 2  magnetic cloud has been reported                    350

# %% [markdown]
# # Train Test split

# %%
# split into inpiut and output elements
X = catogorical_data.drop(['solar wind speed km/s', 
                           'ICME Plasma/Field Start Y/M/D (UT) (b)'], 
                           axis=1)

y = catogorical_data['solar wind speed km/s']

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
# summarize the shape of the training dataset
print(X_train.shape, y_train.shape)
# Out:
# (296, 3) (296,)

# %%
X_test
# Out:
#     forward fast shock happens  \
# 230                         No
# 93                          No
# 205                        Yes
# 435                         No
# 72                          No
# ..                         ...
# 151                        Yes
# 318                         No
# 420                         No
# 404                         No
# 92                         Yes
#
#     Evidence of BiDirectional suprathermal Electron strahls (BDE)*  \
# 230                                        no Evidence
# 93                                       some Evidence
# 205                                      some Evidence
# 435                                      some Evidence
# 72                                       some Evidence
# ..                                                 ...
# 151                                      some Evidence
# 318                                      some Evidence
# 420                                      some Evidence
# 404                                      some Evidence
# 92                                       some Evidence
#
#                      magnetic cloud has been reported*
# 230  evidence of a rotation in field direction, but...
# 93                magnetic cloud has not been reported
# 205               magnetic cloud has not been reported
# 435                   magnetic cloud has been reported
# 72   magnetic cloud has been reported&\nevent repor...
# ..                                                 ...
# 151  evidence of a rotation in field direction, but...
# 318                   magnetic cloud has been reported
# 420                   magnetic cloud has been reported
# 404                   magnetic cloud has been reported
# 92                magnetic cloud has not been reported
#
# [75 rows x 3 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordinal_encoder = OrdinalEncoder()
#fit the transformer on training data only
X_train_trans = ordinal_encoder.fit_transform(X_train)
# use trasnformer and transform the test data set
# avoid data leakage
X_test_trans = ordinal_encoder.transform(X_test)

y_train_np = np.array(y_train)

steps = list()
steps.append(('model', LinearRegression()))
pipeline = Pipeline(steps=steps)


# fit pipeline
pipeline.fit(X_train_trans, 
             y_train_np)

# make predictions
yhat = pipeline.predict(X_test_trans)


print('r2_score ', r2_score(yhat, y_test))
print('mean_absolute_error ', mean_absolute_error(yhat, y_test))
# Out:
# r2_score  -2.4841847997346935
# mean_absolute_error  63.54796615240219

# %%
plt.figure(figsize=(8,8))
plt.scatter(yhat, y_test)
plt.ylabel('prediction - solar wind speed km/s')
plt.xlabel('data - solar wind speed km/s')
plt.axline([0, 0], [800, 800], color ='k')
plt.xlim(0, 800)
plt.ylim(0, 800)
plt.show()
